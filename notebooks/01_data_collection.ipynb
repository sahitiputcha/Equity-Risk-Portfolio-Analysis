# %%
import sys
from pathlib import Path

import pandas as pd

project_root = Path.cwd().parent
sys.path.append(str(project_root))

from src.data_loader import download_market_data

# %%
portfolio_assets = [
    "AAPL",  # Apple
    "JPM",   # JPMorgan Chase
    "JNJ",   # Johnson & Johnson
    "KO",    # Coca-Cola
    "XOM",   # Exxon Mobil
    "GLD",   # Gold ETF
    "TLT"    # Long-Term Treasury Bond ETF
]

benchmark = "SPY"

tickers = portfolio_assets + [benchmark]

tickers
# Out:
# ['AAPL', 'JPM', 'JNJ', 'KO', 'XOM', 'GLD', 'TLT', 'SPY']

# %%
from datetime import date

start_date = "2016-01-01"
end_date = date.today().strftime("%Y-%m-%d")

print(f"Start Date: {start_date}")
print(f"End Date: {end_date}")
# Out:
# Start Date: 2016-01-01
# End Date: 2026-07-23

# %%
market_data = download_market_data(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date
    )

# %%
market_data.head()
# Out:
# Ticker             GLD                                                \
# Price             Open        High         Low       Close    Volume
# Date
# 2016-01-04  103.129997  103.669998  102.489998  102.889999   6440000
# 2016-01-05  103.129997  103.459999  102.930000  103.180000   3500300
# 2016-01-06  104.370003  104.800003  103.930000  104.669998   9316600
# 2016-01-07  105.830002  106.239998  105.190002  106.150002  11730400
# 2016-01-08  105.480003  105.800003  105.040001  105.680000   7678200
#
# Ticker            TLT                                             ...  \
# Price            Open       High        Low      Close    Volume  ...
# Date                                                              ...
# 2016-01-04  91.008037  91.396161  90.552736  90.649765  10591900  ...
# 2016-01-05  90.224345  90.687112  90.060142  90.284058   6242600  ...
# 2016-01-06  91.284222  91.523068  91.097623  91.500671   8916900  ...
# 2016-01-07  91.567857  91.754456  90.903565  91.664886  10202200  ...
# 2016-01-08  91.381276  92.157528  91.231999  92.075424   9577200  ...
#
# Ticker            JNJ                                                    KO  \
# Price            Open       High        Low      Close    Volume       Open
# Date
# 2016-01-04  76.259761  76.334738  74.565265  75.337540  12722800  30.512732
# 2016-01-05  75.412522  76.057331  75.405023  75.652451   6467200  30.491110
# 2016-01-06  74.842678  75.704922  74.677726  75.270050   7733800  30.411836
# 2016-01-07  74.460299  75.045124  74.137895  74.392822   9433100  30.015469
# 2016-01-08  74.887671  74.932662  73.365626  73.598061   9766700  30.015474
#
# Ticker
# Price            High        Low      Close    Volume
# Date
# 2016-01-04  30.628038  30.246089  30.555973  16084100
# 2016-01-05  30.721720  30.390215  30.664066  15781900
# 2016-01-06  30.635238  30.296530  30.498314  16245100
# 2016-01-07  30.346971  29.871336  29.993847  20563600
# 2016-01-08  30.354182  29.842515  29.914579  14645900
#
# [5 rows x 40 columns]

# %%
market_data.columns
# Out:
# MultiIndex([( 'GLD',   'Open'),
#             ( 'GLD',   'High'),
#             ( 'GLD',    'Low'),
#             ( 'GLD',  'Close'),
#             ( 'GLD', 'Volume'),
#             ( 'TLT',   'Open'),
#             ( 'TLT',   'High'),
#             ( 'TLT',    'Low'),
#             ( 'TLT',  'Close'),
#             ( 'TLT', 'Volume'),
#             ( 'SPY',   'Open'),
#             ( 'SPY',   'High'),
#             ( 'SPY',    'Low'),
#             ( 'SPY',  'Close'),
#             ( 'SPY', 'Volume'),
#             ( 'JPM',   'Open'),
#             ( 'JPM',   'High'),
#             ( 'JPM',    'Low'),
#             ( 'JPM',  'Close'),
#             ( 'JPM', 'Volume'),
#             ( 'XOM',   'Open'),
#             ( 'XOM',   'High'),
#             ( 'XOM',    'Low'),
#             ( 'XOM',  'Close'),
#             ( 'XOM', 'Volume'),
#             ('AAPL',   'Open'),
#             ('AAPL',   'High'),
#             ('AAPL',    'Low'),
#             ('AAPL',  'Close'),
#             ('AAPL', 'Volume'),
#             ( 'JNJ',   'Open'),
#             ( 'JNJ',   'High'),
#             ( 'JNJ',    'Low'),
#             ( 'JNJ',  'Close'),
#             ( 'JNJ', 'Volume'),
#             (  'KO',   'Open'),
#             (  'KO',   'High'),
#             (  'KO',    'Low'),
#             (  'KO',  'Close'),
#             (  'KO', 'Volume')],
#            names=['Ticker', 'Price'])

# %%
market_data.columns.levels
# Out:
# FrozenList([['AAPL', 'GLD', 'JNJ', 'JPM', 'KO', 'SPY', 'TLT', 'XOM'], ['Close', 'High', 'Low', 'Open', 'Volume']])

# %%
market_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2652 entries, 2016-01-04 to 2026-07-22
# Data columns (total 40 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (GLD, Open)     2652 non-null   float64
#  1   (GLD, High)     2652 non-null   float64
#  2   (GLD, Low)      2652 non-null   float64
#  3   (GLD, Close)    2652 non-null   float64
#  4   (GLD, Volume)   2652 non-null   int64
#  5   (TLT, Open)     2652 non-null   float64
#  6   (TLT, High)     2652 non-null   float64
#  7   (TLT, Low)      2652 non-null   float64
#  8   (TLT, Close)    2652 non-null   float64
#  9   (TLT, Volume)   2652 non-null   int64
#  10  (SPY, Open)     2652 non-null   float64
#  11  (SPY, High)     2652 non-null   float64
#  12  (SPY, Low)      2652 non-null   float64
#  13  (SPY, Close)    2652 non-null   float64
#  14  (SPY, Volume)   2652 non-null   int64
#  15  (JPM, Open)     2652 non-null   float64
#  16  (JPM, High)     2652 non-null   float64
#  17  (JPM, Low)      2652 non-null   float64
#  18  (JPM, Close)    2652 non-null   float64
#  19  (JPM, Volume)   2652 non-null   int64
#  20  (XOM, Open)     2652 non-null   float64
#  21  (XOM, High)     2652 non-null   float64
#  22  (XOM, Low)      2652 non-null   float64
#  23  (XOM, Close)    2652 non-null   float64
#  24  (XOM, Volume)   2652 non-null   int64
#  25  (AAPL, Open)    2652 non-null   float64
#  26  (AAPL, High)    2652 non-null   float64
#  27  (AAPL, Low)     2652 non-null   float64
#  28  (AAPL, Close)   2652 non-null   float64
#  29  (AAPL, Volume)  2652 non-null   int64
#  30  (JNJ, Open)     2652 non-null   float64
#  31  (JNJ, High)     2652 non-null   float64
#  32  (JNJ, Low)      2652 non-null   float64
#  33  (JNJ, Close)    2652 non-null   float64
#  34  (JNJ, Volume)   2652 non-null   int64
#  35  (KO, Open)      2652 non-null   float64
#  36  (KO, High)      2652 non-null   float64
#  37  (KO, Low)       2652 non-null   float64
#  38  (KO, Close)     2652 non-null   float64
#  39  (KO, Volume)    2652 non-null   int64
# dtypes: float64(32), int64(8)
# memory usage: 849.5 KB

# %%
close_prices = market_data.xs("Close", level=1, axis=1)
close_prices.head()
# Out:
# Ticker             GLD        TLT         SPY        JPM        XOM  \
# Date
# 2016-01-04  102.889999  90.649765  169.471558  48.184082  49.319611
# 2016-01-05  103.180000  90.284058  169.758179  48.267384  49.739857
# 2016-01-06  104.669998  91.500671  167.616837  47.570599  49.325985
# 2016-01-07  106.150002  91.664886  163.595413  45.646862  48.536465
# 2016-01-08  105.680000  92.075424  161.799667  44.624424  47.555916
#
# Ticker           AAPL        JNJ         KO
# Date
# 2016-01-04  23.709105  75.337540  30.555973
# 2016-01-05  23.114973  75.652451  30.664066
# 2016-01-06  22.662617  75.270050  30.498314
# 2016-01-07  21.706154  74.392822  29.993847
# 2016-01-08  21.820930  73.598061  29.914579

# %%
close_prices.shape
# Out:
# (2652, 8)

# %%
close_prices.isnull().sum()
# Out:
# Ticker
# GLD     0
# TLT     0
# SPY     0
# JPM     0
# XOM     0
# AAPL    0
# JNJ     0
# KO      0
# dtype: int64

# %%
close_prices.describe()
# Out:
# Ticker          GLD          TLT          SPY          JPM          XOM  \
# count   2652.000000  2652.000000  2652.000000  2652.000000  2652.000000
# mean     184.415309   100.091435   370.990893   134.841437    73.542328
# std       81.707377    16.128076   154.300229    74.730603    30.372043
# min      102.889999    73.702682   154.161621    40.193783    23.823559
# 25%      124.150000    87.113323   241.679512    84.728525    52.674911
# 50%      166.580002    95.643936   359.289185   112.144310    57.587599
# 75%      187.462505   111.539547   443.357903   150.755459   100.287704
# max      495.899994   142.699524   757.618225   348.209991   170.313995
#
# Ticker         AAPL          JNJ           KO
# count   2652.000000  2652.000000  2652.000000
# mean     122.608075   134.051215    48.272084
# std       80.217215    34.920977    13.351536
# min       20.565865    71.791107    29.820902
# 25%       42.645570   107.572464    35.986016
# 50%      127.044315   138.087601    46.551842
# 75%      180.529194   150.289127    56.854677
# max      333.739990   267.239990    84.919998

# %%
from pathlib import Path

processed_path = project_root / "data" / "processed"
processed_path.mkdir(parents=True, exist_ok=True)

close_prices.to_csv(processed_path / "close_prices.csv")

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
processed_path
# Out:
# WindowsPath('c:/Users/Sahiti Putcha/Documents/Equity-Risk-Portfolio-Analysis/data/processed')
