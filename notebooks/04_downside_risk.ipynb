# %% [markdown]
# #Phase 4: Downside Risk

# %% [markdown]
# ##1 Imports

# %%
import sys 
from pathlib import Path 

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

project_root  = Path.cwd().parent
sys.path.append(str(project_root))

# %%
data_path = project_root / "data" / "processed" / "daily_returns.csv"

daily_returns = pd.read_csv(
    data_path, 
    index_col = 0,
    parse_dates= True
)
daily_returns.head()
# Out:
#                  GLD       TLT       SPY       JPM       XOM      AAPL  \
# Date
# 2016-01-05  0.002819 -0.004034  0.001691  0.001729  0.008521 -0.025059
# 2016-01-06  0.014441  0.013475 -0.012614 -0.014436 -0.008321 -0.019570
# 2016-01-07  0.014140  0.001795 -0.023992 -0.040440 -0.016006 -0.042204
# 2016-01-08 -0.004428  0.004479 -0.010977 -0.022399 -0.020202  0.005288
# 2016-01-11 -0.008895 -0.010944  0.000990 -0.001528 -0.013388  0.016192
#
#                  JNJ        KO
# Date
# 2016-01-05  0.004180  0.003538
# 2016-01-06 -0.005055 -0.005405
# 2016-01-07 -0.011654 -0.016541
# 2016-01-08 -0.010683 -0.002643
# 2016-01-11 -0.006010  0.001687

# %% [markdown]
# ##2 Load Daily Returns

# %%
weights = np.array([1/8]*8)
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()
# Out:
# Date
# 2016-01-05   -0.000827
# 2016-01-06   -0.004686
# 2016-01-07   -0.016863
# 2016-01-08   -0.007696
# 2016-01-11   -0.002737
# dtype: float64

# %%
portfolio_value = (1+portfolio_returns).cumprod()
portfolio_value.head()
# Out:
# Date
# 2016-01-05    0.999173
# 2016-01-06    0.994491
# 2016-01-07    0.977721
# 2016-01-08    0.970197
# 2016-01-11    0.967542
# dtype: float64

# %%
running_max = portfolio_value.cummax()
running_max.head()
# Out:
# Date
# 2016-01-05    0.999173
# 2016-01-06    0.999173
# 2016-01-07    0.999173
# 2016-01-08    0.999173
# 2016-01-11    0.999173
# dtype: float64

# %% [markdown]
# ##3 Maximum Drawdown

# %%
drawdown = (portfolio_value - running_max)/running_max
drawdown.head()
# Out:
# Date
# 2016-01-05    0.000000
# 2016-01-06   -0.004686
# 2016-01-07   -0.021469
# 2016-01-08   -0.029000
# 2016-01-11   -0.031658
# dtype: float64

# %%
max_drawdown = drawdown.min()
print(f"maximum drawdown: {max_drawdown:.2%}")
# Out:
# maximum drawdown: -26.93%

# %% [markdown]
# ##4 Value at Risk(VaR)

# %%
var_95 = portfolio_returns.quantile(0.05)
print(f"95% daily var: {var_95:.2%}")
# Out:
# 95% daily var: -1.09%
